# %% [markdown]
# ## Mean

# %%
import numpy
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
x = numpy.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %% [markdown]
# ## Median

# %%
x = numpy.median(speed)
print(x)
# Out:
# 87.0

# %% [markdown]
# ## Mode

# %%
from scipy import stats
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=86, count=3)

# %% [markdown]
# ## Standard Deviation

# %%
import numpy
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
x = numpy.std(speed)
print(x)
# Out:
# 9.258292301032677

# %% [markdown]
# ## Variance

# %%
import numpy
speed = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]
x = numpy.var(speed)
print(x)
# Out:
# 85.71597633136093

# %% [markdown]
# ## Percentile

# %%
import numpy
ages = [5, 31, 43, 48, 50, 41, 7, 11, 15, 39, 80, 82, 32, 2, 8, 6, 25, 36, 27, 61, 31]
x = numpy.percentile(ages, 90)
print(x)
# Out:
# 61.0

# %% [markdown]
# ## Uniform Data Distribution

# %%
import numpy
x = numpy.random.uniform(0.0, 5.0, 250)
print(x)
# Out:
# [0.08067059 2.18641657 3.64722479 2.06244997 0.33156928 3.05722182
#  4.09123639 4.63913419 2.72520194 2.98093244 2.22268291 2.14689494
#  4.47087686 3.48705133 2.41444938 2.84309107 3.83099357 3.23651644
#  1.75344069 0.17332162 1.1001866  3.50347014 1.1212862  4.2463527
#  0.12362784 4.06173049 2.89559546 1.27451693 4.20884052 3.78157785
#  3.83350856 4.56620933 2.86405279 4.39455195 2.58793327 3.55104438
#  2.46912118 1.50659415 1.43518643 4.63846385 4.6171413  4.79943338
#  0.27425552 1.32024148 1.64363059 2.762642   0.95303187 0.99316301
#  1.34086834 3.62644119 3.08353952 0.22309371 2.10480069 0.930362
#  1.19697668 4.57431173 0.44471581 3.57303946 3.84981479 2.26639875
#  0.83256925 2.3422409  3.82067327 3.06339837 4.36907902 2.73311407
#  3.58801994 2.92874371 2.39279233 1.17030254 0.60013364 1.68149559
#  0.6555628  4.37467045 4.64596814 0.75613198 2.99750301 0.26695973
#  1.6152173  2.27182941 3.568703   4.34421896 1.70999091 4.16182866
#  1.67640364 0.1515067  4.26555215 0.37110441 3.30871505 4.71416524
#  4.32270802 2.48426867 1.2560545  0.93952534 2.19085475 2.3663463
#  0.69340392 2.53242178 4.25241772 1.96117992 3.61648934 3.26340381
#  3.706267   1.40011505 0.38765285 0.11706709 1.59906186 0.73783956
#  4.89630605 0.6515187  2.13878362 4.45851785 3.07793429 2.77731481
#  3.37568508 4.98365539 2.45134458 1.62542067 2.16398072 1.03609761
#  4.84039673 3.20389987 1.23437717 4.78952787 1.00986056 2.52473682
#  4.90530264 1.22494385 4.61621338 2.62978661 2.01673317 3.71171524
#  2.52823631 3.38259119 3.90063807 2.52708052 3.75396927 0.82834861
#  2.46797559 0.72009225 2.30558275 3.30414992 4.58728514 1.56594696
#  1.57516437 4.56036018 1.68812214 0.74292986 2.75586651 3.31694192
#  3.38887335 2.17154689 2.94032526 2.7640634  1.98303914 3.28715677
#  3.54662262 0.08614999 3.61969293 3.50630734 3.18430069 0.04862763
#  1.61450704 3.13748174 0.05806644 3.88255782 1.69480448 1.63505371
#  0.03211498 1.90094309 1.68121217 0.29111582 0.35670617 4.31602315
#  0.86178171 3.84033641 2.21272547 3.0608006  1.0705659  1.07875642
#  0.75058969 4.15188374 1.85597769 4.57362365 2.35192406 1.23394287
#  2.70995281 2.33190708 1.24950278 1.91474543 4.65714543 2.34528396
#  1.13271283 4.96291788 1.23032875 1.71746737 1.51249163 3.28717392
#  2.01826969 4.27970536 2.73640573 3.59677612 3.52903329 4.0337328
#  0.07233835 1.44061465 4.20913986 0.53457658 0.43866594 1.63000997
#  3.87660619 1.71117192 4.15875471 1.14536991 2.32647909 1.47192184
#  3.58020528 1.91229239 1.92143512 3.95575446 1.82445491 0.4344438
#  2.9807901  2.04519195 2.42233103 0.70283253 4.58905158 1.80816412
#  0.7230666  1.79453156 1.1366833  2.84223115 0.58223908 1.65555024
#  0.80964928 4.15451969 3.76499603 3.1847271  1.02446186 4.72027048
#  2.29076403 3.14824229 2.33981117 2.6188831  0.18477979 2.56393181
#  0.32897848 1.23187759 4.23654946 2.20844013]

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5) # data, no. of bars
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# ## Normal Data Distribution (Gaussian Curve, Bell Curve)

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
import matplotlib.pyplot as plt

x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6] # age
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86] # speed

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Sort

# %%
import numpy

y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86] # speed

x = numpy.sort(y)

print(x)
# Out:
# [ 77  78  85  86  86  86  87  87  88  94  99 103 111]
