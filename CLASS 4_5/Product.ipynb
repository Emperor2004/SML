# %% [markdown]
# # Product Performance Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv("Practice Product performance.csv")
dataset.head()
# Out:
#    Ambience  Customer_service  Offers  Product_range  Performance
# 0      0.50              1.40   -0.68           0.48            2
# 1     -0.14              0.92   -0.14           0.11            7
# 2      0.65              0.06   -0.79           0.51            5
# 3      1.52             -0.65   -0.31           1.12            9
# 4     -0.23              0.70   -1.89           1.10            8

# %%
dataset.shape
# Out:
# (1000, 5)

# %%
from matplotlib import pyplot as plt
dataset['Ambience'].plot(kind='hist', bins=20, title='Ambience')
plt.show()

# %%
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x='Ambience', y='Performance', alpha=0.5)
plt.show()

# %%
sns.pairplot(data=dataset, height=2)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    vif = pd.DataFrame()
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return (vif)

# %%
X = dataset.iloc[:, :-1]
calc_vif(X)
# Out:
#         VIF
# 0  3.007233
# 1  2.548359
# 2  2.581965
# 3  5.950350

# %%
x = dataset[['Ambience', 'Customer_service', 'Offers', 'Product_range']]
y = dataset['Performance']

# %%
x.head()
# Out:
#    Ambience  Customer_service  Offers  Product_range
# 0      0.50              1.40   -0.68           0.48
# 1     -0.14              0.92   -0.14           0.11
# 2      0.65              0.06   -0.79           0.51
# 3      1.52             -0.65   -0.31           1.12
# 4     -0.23              0.70   -1.89           1.10

# %%
x.shape
# Out:
# (1000, 4)

# %%
y
# Out:
# 0      2
# 1      7
# 2      5
# 3      9
# 4      8
#       ..
# 995    2
# 996    9
# 997    6
# 998    2
# 999    2
# Name: Performance, Length: 1000, dtype: int64

# %%
y.shape
# Out:
# (1000,)
